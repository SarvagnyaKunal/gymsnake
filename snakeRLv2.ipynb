# %%
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque
import numpy as np
import pygame
import torch.nn.functional as F
import time
from snake_game import SnakeEnv
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# cuda

# %%
class DQNNet(nn.Module):
    def __init__(self, input_dim=12, hidden_dim=512, output_dim=4):  # Changed from 8 to 12
        super().__init__()
        # Deeper network with residual connections for better learning
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.ln1 = nn.LayerNorm(hidden_dim)
        
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.ln2 = nn.LayerNorm(hidden_dim)
        
        self.fc3 = nn.Linear(hidden_dim, hidden_dim // 2)
        self.ln3 = nn.LayerNorm(hidden_dim // 2)
        
        self.fc4 = nn.Linear(hidden_dim // 2, hidden_dim // 4)
        self.ln4 = nn.LayerNorm(hidden_dim // 4)
        
        # Dueling DQN architecture: separate value and advantage streams
        self.value_stream = nn.Linear(hidden_dim // 4, 1)
        self.advantage_stream = nn.Linear(hidden_dim // 4, output_dim)
        
        # Initialize weights properly
        self._init_weights()
    
    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.orthogonal_(m.weight, gain=np.sqrt(2))
                nn.init.constant_(m.bias, 0.0)
    
    def forward(self, x):
        x = F.relu(self.ln1(self.fc1(x)))
        x = F.relu(self.ln2(self.fc2(x)))
        x = F.relu(self.ln3(self.fc3(x)))
        x = F.relu(self.ln4(self.fc4(x)))
        
        # Dueling DQN: Q(s,a) = V(s) + (A(s,a) - mean(A(s,a)))
        value = self.value_stream(x)
        advantages = self.advantage_stream(x)
        q_values = value + (advantages - advantages.mean(dim=1, keepdim=True))
        
        return q_values

# %%
class ReplayBuffer:
    def __init__(self, max_size=50000):  # Increased buffer size
        self.buffer = deque(maxlen=max_size)
    
    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))
    
    def sample(self, batch_size, device):
        batch = random.sample(self.buffer, batch_size)
        s, a, r, ns, d = zip(*batch)
        return (torch.tensor(s, dtype=torch.float32, device=device),
                torch.tensor(a, dtype=torch.long, device=device),
                torch.tensor(r, dtype=torch.float32, device=device),
                torch.tensor(ns, dtype=torch.float32, device=device),
                torch.tensor(d, dtype=torch.float32, device=device))
    
    def __len__(self):
        return len(self.buffer)

# %%
env = SnakeEnv()
dqn = DQNNet().to(device)
target_dqn = DQNNet().to(device)
target_dqn.load_state_dict(dqn.state_dict())
target_dqn.eval()

# Use Adam with weight decay for regularization
optimizer = optim.Adam(dqn.parameters(), lr=3e-4, weight_decay=1e-5)
# Learning rate scheduler for better convergence
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1000, gamma=0.9)

replay = ReplayBuffer()
gamma = 0.9999  # Higher discount for very long-term planning
epsilon = 1.0
epsilon_min = 0.05  # Keep some exploration
epsilon_decay = 0.9998  # Much slower decay for more exploration
batch_size = 64
update_target_every = 200  # Less frequent updates for stability
num_episodes = 30000
best_score = 0
moving_avg_reward = []
moving_avg_score = []

# %%
for episode in range(num_episodes):
    state = env.reset()
    total_reward = 0
    steps = 0
    max_steps = 10000  # Prevent infinite loops

    while True:
        steps += 1
        # Epsilon-greedy exploration
        if random.random() < epsilon:
            action = random.randint(0, 3)
        else:
            with torch.no_grad():
                state_tensor = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)  # Add batch dimension
                q_values = dqn(state_tensor)
                action = torch.argmax(q_values).item()
        
        # Environment step
        next_state, reward, done = env.step(action)
        
        # Add timeout penalty to prevent wandering
        if steps >= max_steps:
            done = True
            reward -= 5.0
        
        replay.push(state, action, reward, next_state, done)
        total_reward += reward
        state = next_state

        # Train network more frequently
        if len(replay) >= batch_size * 2:  # Start training after enough samples
            s, a, r, ns, d = replay.sample(batch_size, device)

            # Double DQN: use online network to select action, target network to evaluate
            q_vals = dqn(s).gather(1, a.unsqueeze(1)).squeeze()

            with torch.no_grad():
                # Select best action using online network
                next_actions = dqn(ns).max(1)[1]
                # Evaluate using target network
                q_next = target_dqn(ns).gather(1, next_actions.unsqueeze(1)).squeeze()
                q_target = r + gamma * q_next * (1 - d)

            # Huber loss for robustness
            loss = F.smooth_l1_loss(q_vals, q_target)
            
            optimizer.zero_grad()
            loss.backward()
            # Gradient clipping to prevent exploding gradients
            torch.nn.utils.clip_grad_norm_(dqn.parameters(), max_norm=10.0)
            optimizer.step()

        # Handle pygame events and render during gameplay
        if episode % 10 == 0:
            for event in pygame.event.get():
                if event.type == pygame.QUIT:
                    pygame.quit()
                    exit()
            env.render()
        
        if done:
            break

    # Handle pygame events even when not rendering
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            exit()

    # Update target network
    if episode % update_target_every == 0 and episode > 0:
        target_dqn.load_state_dict(dqn.state_dict())
    
    epsilon = max(epsilon_min, epsilon * epsilon_decay)
    # Step learning rate scheduler
    scheduler.step()
    
    # Track moving average reward and score
    moving_avg_reward.append(total_reward)
    moving_avg_score.append(env.score)
    if len(moving_avg_reward) > 100:
        moving_avg_reward.pop(0)
        moving_avg_score.pop(0)
    avg_reward = np.mean(moving_avg_reward)
    avg_score = np.mean(moving_avg_score)

    # Save best model based on score
    if env.score > best_score:
        torch.save(dqn.state_dict(), "best_snake_model.pth")
    
    print(f"Ep:{episode:5d} | Reward:{total_reward:7.2f} | AvgR:{avg_reward:6.2f} | Score:{env.score:3d} | AvgS:{avg_score:5.2f} | Eps:{epsilon:.4f} | Steps:{steps:4d}")

print("\n🎉 Training complete!")
print(f"Best score achieved: {best_score}")
# Out:
# Ep:    0 | Reward: -18.00 | AvgR:-18.00 | Score:  0 | AvgS: 0.00 | Eps:0.9998 | Steps: 195
# Ep:    1 | Reward: -15.00 | AvgR:-16.50 | Score:  0 | AvgS: 0.00 | Eps:0.9996 | Steps:  13
# Ep:    2 | Reward: -16.00 | AvgR:-16.33 | Score:  0 | AvgS: 0.00 | Eps:0.9994 | Steps:  25
# Ep:    3 | Reward: -17.50 | AvgR:-16.62 | Score:  0 | AvgS: 0.00 | Eps:0.9992 | Steps:  28
# Ep:    4 | Reward: -21.00 | AvgR:-17.50 | Score:  0 | AvgS: 0.00 | Eps:0.9990 | Steps:  85
# Ep:    5 | Reward: -22.50 | AvgR:-18.33 | Score:  0 | AvgS: 0.00 | Eps:0.9988 | Steps:  58
# Ep:    6 | Reward: -15.50 | AvgR:-17.93 | Score:  0 | AvgS: 0.00 | Eps:0.9986 | Steps:   2
# Ep:    7 | Reward: -15.50 | AvgR:-17.62 | Score:  0 | AvgS: 0.00 | Eps:0.9984 | Steps:   2
# Ep:  108 | Reward: -20.50 | AvgR:-16.37 | Score:  0 | AvgS: 0.09 | Eps:0.9784 | Steps: 126
# Ep:  109 | Reward: -14.00 | AvgR:-16.39 | Score:  0 | AvgS: 0.08 | Eps:0.9782 | Steps:  33
# Ep:  110 | Reward: -16.00 | AvgR:-16.34 | Score:  0 | AvgS: 0.07 | Eps:0.9780 | Steps:   3
# Ep:  111 | Reward:  -9.50 | AvgR:-16.36 | Score:  0 | AvgS: 0.07 | Eps:0.9778 | Steps:  32
# Ep:  112 | Reward: -20.00 | AvgR:-16.39 | Score:  0 | AvgS: 0.07 | Eps:0.9777 | Steps:  11
# Ep:  113 | Reward: -22.00 | AvgR:-16.45 | Score:  0 | AvgS: 0.07 | Eps:0.9775 | Steps: 163
# Ep:  114 | Reward: -20.00 | AvgR:-16.46 | Score:  0 | AvgS: 0.07 | Eps:0.9773 | Steps:  17
# Ep:  115 | Reward: -11.50 | AvgR:-16.43 | Score:  0 | AvgS: 0.06 | Eps:0.9771 | Steps:  78
# Ep:  116 | Reward:  -9.50 | AvgR:-16.32 | Score:  0 | AvgS: 0.06 | Eps:0.9769 | Steps: 116
# Ep:  117 | Reward:  -7.50 | AvgR:-16.17 | Score:  0 | AvgS: 0.06 | Eps:0.9767 | Steps:  58
# Ep:  118 | Reward: -13.00 | AvgR:-16.14 | Score:  0 | AvgS: 0.06 | Eps:0.9765 | Steps:  45
# Ep:  119 | Reward: -16.50 | AvgR:-16.12 | Score:  0 | AvgS: 0.06 | Eps:0.9763 | Steps:   8
# Ep:  120 | Reward: -16.50 | AvgR:-16.11 | Score:  0 | AvgS: 0.06 | Eps:0.9761 | Steps:  16
# Ep:  121 | Reward: -21.50 | AvgR:-16.12 | Score:  0 | AvgS: 0.06 | Eps:0.9759 | Steps:  26
# Ep:  122 | Reward: -19.00 | AvgR:-16.11 | Score:  0 | AvgS: 0.06 | Eps:0.9757 | Steps:  13
# Ep:  123 | Reward: -20.50 | AvgR:-16.16 | Score:  0 | AvgS: 0.06 | Eps:0.9755 | Steps:  30
# Ep:  124 | Reward: -15.50 | AvgR:-16.14 | Score:  0 | AvgS: 0.06 | Eps:0.9753 | Steps:   4
# Ep:  125 | Reward: -21.00 | AvgR:-16.24 | Score:  0 | AvgS: 0.06 | Eps:0.9751 | Steps:  99
# Ep:  126 | Reward:  -9.50 | AvgR:-16.20 | Score:  1 | AvgS: 0.07 | Eps:0.9749 | Steps: 170
# Ep:  127 | Reward: -13.50 | AvgR:-16.11 | Score:  0 | AvgS: 0.07 | Eps:0.9747 | Steps:  56
# Ep:  128 | Reward:  -9.00 | AvgR:-16.14 | Score:  0 | AvgS: 0.06 | Eps:0.9745 | Steps:  75
# Ep:  129 | Reward: -12.50 | AvgR:-16.09 | Score:  1 | AvgS: 0.07 | Eps:0.9743 | Steps: 116
# Ep:  130 | Reward: -10.50 | AvgR:-16.04 | Score:  0 | AvgS: 0.07 | Eps:0.9741 | Steps:  32
# Ep:  131 | Reward: -19.00 | AvgR:-16.06 | Score:  0 | AvgS: 0.07 | Eps:0.9739 | Steps: 117
# Ep:  408 | Reward:  -6.50 | AvgR:-15.21 | Score:  1 | AvgS: 0.17 | Eps:0.9214 | Steps: 120
# Ep:  409 | Reward: -20.00 | AvgR:-15.24 | Score:  0 | AvgS: 0.16 | Eps:0.9213 | Steps: 157
# Ep:  410 | Reward: -15.50 | AvgR:-15.23 | Score:  0 | AvgS: 0.16 | Eps:0.9211 | Steps:   2
# Ep:  411 | Reward: -16.50 | AvgR:-15.22 | Score:  0 | AvgS: 0.16 | Eps:0.9209 | Steps:  28
# Ep:  412 | Reward: -16.00 | AvgR:-15.25 | Score:  0 | AvgS: 0.16 | Eps:0.9207 | Steps: 179
# Ep:  413 | Reward:  -5.00 | AvgR:-15.14 | Score:  1 | AvgS: 0.17 | Eps:0.9205 | Steps: 131
# Ep:  414 | Reward: -11.00 | AvgR:-15.12 | Score:  2 | AvgS: 0.19 | Eps:0.9203 | Steps:  87
# Ep:  415 | Reward: -14.00 | AvgR:-15.11 | Score:  0 | AvgS: 0.19 | Eps:0.9202 | Steps:  17
# Ep:  416 | Reward: -21.50 | AvgR:-15.19 | Score:  0 | AvgS: 0.19 | Eps:0.9200 | Steps:  48
# Ep:  417 | Reward: -11.50 | AvgR:-15.22 | Score:  0 | AvgS: 0.18 | Eps:0.9198 | Steps:  60
# Ep:  418 | Reward: -10.00 | AvgR:-15.15 | Score:  1 | AvgS: 0.19 | Eps:0.9196 | Steps: 107
# Ep:  419 | Reward:  -9.50 | AvgR:-15.09 | Score:  1 | AvgS: 0.19 | Eps:0.9194 | Steps:  68
# Ep:  420 | Reward: -11.50 | AvgR:-15.07 | Score:  1 | AvgS: 0.20 | Eps:0.9192 | Steps: 132
# Ep:  421 | Reward: -22.50 | AvgR:-15.14 | Score:  0 | AvgS: 0.20 | Eps:0.9191 | Steps:  62
# Ep:  422 | Reward: -12.00 | AvgR:-15.15 | Score:  0 | AvgS: 0.18 | Eps:0.9189 | Steps:  37
# Ep:  423 | Reward: -19.00 | AvgR:-15.15 | Score:  0 | AvgS: 0.18 | Eps:0.9187 | Steps: 167
# Ep:  424 | Reward: -17.00 | AvgR:-15.21 | Score:  0 | AvgS: 0.18 | Eps:0.9185 | Steps:   7
# Ep:  425 | Reward: -15.50 | AvgR:-15.21 | Score:  0 | AvgS: 0.18 | Eps:0.9183 | Steps:  42
# Ep:  426 | Reward:  -6.00 | AvgR:-15.20 | Score:  1 | AvgS: 0.18 | Eps:0.9181 | Steps:  95
# Ep:  427 | Reward: -18.50 | AvgR:-15.29 | Score:  0 | AvgS: 0.17 | Eps:0.9180 | Steps:  10
# Ep:  428 | Reward: -18.00 | AvgR:-15.35 | Score:  0 | AvgS: 0.17 | Eps:0.9178 | Steps:  13
# Ep:  429 | Reward: -10.50 | AvgR:-15.26 | Score:  0 | AvgS: 0.17 | Eps:0.9176 | Steps: 118
# Ep:  430 | Reward:  -8.00 | AvgR:-15.16 | Score:  0 | AvgS: 0.17 | Eps:0.9174 | Steps:  95
# Ep:  526 | Reward: -18.50 | AvgR:-13.54 | Score:  0 | AvgS: 0.23 | Eps:0.9000 | Steps:   8
# ...
# Ep:29829 | Reward:  28.50 | AvgR:130.62 | Score:  9 | AvgS:20.19 | Eps:0.0500 | Steps: 106
# Ep:29830 | Reward: 146.50 | AvgR:131.71 | Score: 25 | AvgS:20.36 | Eps:0.0500 | Steps: 416
# Ep:29831 | Reward:  74.00 | AvgR:130.39 | Score: 17 | AvgS:20.20 | Eps:0.0500 | Steps: 229
# Ep:29832 | Reward: 178.50 | AvgR:130.82 | Score: 28 | AvgS:20.25 | Eps:0.0500 | Steps: 506
# Ep:29833 | Reward: 178.50 | AvgR:131.37 | Score: 29 | AvgS:20.37 | Eps:0.0500 | Steps: 466
# Ep:29834 | Reward:  80.00 | AvgR:129.78 | Score: 16 | AvgS:20.15 | Eps:0.0500 | Steps: 239
# Ep:29835 | Reward: 195.50 | AvgR:129.24 | Score: 27 | AvgS:20.08 | Eps:0.0500 | Steps: 548
# Ep:29836 | Reward: 205.50 | AvgR:129.19 | Score: 31 | AvgS:20.10 | Eps:0.0500 | Steps: 570
# Ep:29837 | Reward:  16.00 | AvgR:128.51 | Score:  4 | AvgS:19.98 | Eps:0.0500 | Steps:  71
# Ep:29838 | Reward: 198.50 | AvgR:129.86 | Score: 34 | AvgS:20.21 | Eps:0.0500 | Steps: 555
# Ep:29839 | Reward: 172.00 | AvgR:129.70 | Score: 27 | AvgS:20.13 | Eps:0.0500 | Steps: 463
# Ep:29840 | Reward: 112.00 | AvgR:128.38 | Score: 19 | AvgS:19.93 | Eps:0.0500 | Steps: 317
# Ep:29841 | Reward:  20.50 | AvgR:125.06 | Score:  4 | AvgS:19.53 | Eps:0.0500 | Steps:  86
# Ep:29842 | Reward: 118.00 | AvgR:125.56 | Score: 16 | AvgS:19.57 | Eps:0.0500 | Steps: 331
# Ep:29843 | Reward: 134.50 | AvgR:126.64 | Score: 22 | AvgS:19.73 | Eps:0.0500 | Steps: 413
# Ep:29844 | Reward:  93.00 | AvgR:126.64 | Score: 14 | AvgS:19.75 | Eps:0.0500 | Steps: 265
# Ep:29845 | Reward: 188.50 | AvgR:126.07 | Score: 28 | AvgS:19.72 | Eps:0.0500 | Steps: 538
# Ep:29846 | Reward:  30.50 | AvgR:125.90 | Score:  4 | AvgS:19.67 | Eps:0.0500 | Steps: 106
# Ep:29847 | Reward:  55.00 | AvgR:124.91 | Score:  6 | AvgS:19.49 | Eps:0.0500 | Steps: 157
# Ep:29848 | Reward:  40.50 | AvgR:124.95 | Score:  8 | AvgS:19.49 | Eps:0.0500 | Steps: 134
# Ep:29849 | Reward:  55.50 | AvgR:123.38 | Score:  8 | AvgS:19.30 | Eps:0.0500 | Steps: 172
# Ep:29850 | Reward: 283.00 | AvgR:123.95 | Score: 41 | AvgS:19.40 | Eps:0.0500 | Steps: 751
# Ep:29851 | Reward: 292.50 | AvgR:126.09 | Score: 35 | AvgS:19.60 | Eps:0.0500 | Steps: 725
# Ep:29852 | Reward: 172.50 | AvgR:127.01 | Score: 29 | AvgS:19.75 | Eps:0.0500 | Steps: 458
# Ep:29853 | Reward: 195.50 | AvgR:127.81 | Score: 24 | AvgS:19.83 | Eps:0.0500 | Steps: 525
# Ep:29854 | Reward:  72.00 | AvgR:126.71 | Score: 13 | AvgS:19.69 | Eps:0.0500 | Steps: 223
# Ep:29855 | Reward: 154.50 | AvgR:127.21 | Score: 22 | AvgS:19.76 | Eps:0.0500 | Steps: 396
# Ep:29856 | Reward:  63.00 | AvgR:127.67 | Score:  9 | AvgS:19.78 | Eps:0.0500 | Steps: 179
# Ep:29857 | Reward: 131.00 | AvgR:127.48 | Score: 22 | AvgS:19.77 | Eps:0.0500 | Steps: 365
# Ep:29858 | Reward:  58.50 | AvgR:126.11 | Score:  8 | AvgS:19.53 | Eps:0.0500 | Steps: 168
# Ep:29859 | Reward: 157.50 | AvgR:124.56 | Score: 29 | AvgS:19.42 | Eps:0.0500 | Steps: 452
# Ep:29860 | Reward: 132.50 | AvgR:124.77 | Score: 22 | AvgS:19.43 | Eps:0.0500 | Steps: 358
# Ep:29861 | Reward: 156.00 | AvgR:125.83 | Score: 20 | AvgS:19.51 | Eps:0.0500 | Steps: 403
# Ep:29862 | Reward:  75.50 | AvgR:125.28 | Score: 17 | AvgS:19.49 | Eps:0.0500 | Steps: 250
# Ep:29863 | Reward:  21.00 | AvgR:124.23 | Score:  4 | AvgS:19.30 | Eps:0.0500 | Steps:  87
# Ep:29864 | Reward:  60.50 | AvgR:124.36 | Score:  8 | AvgS:19.28 | Eps:0.0500 | Steps: 168
# Ep:29865 | Reward: 170.00 | AvgR:123.97 | Score: 30 | AvgS:19.29 | Eps:0.0500 | Steps: 451
# Ep:29866 | Reward:  15.00 | AvgR:123.28 | Score:  5 | AvgS:19.24 | Eps:0.0500 | Steps:  73
# Ep:29867 | Reward:  49.50 | AvgR:122.94 | Score: 10 | AvgS:19.19 | Eps:0.0500 | Steps: 160
# Ep:29868 | Reward:  53.50 | AvgR:121.61 | Score: 11 | AvgS:19.03 | Eps:0.0500 | Steps: 165
# Ep:29869 | Reward: 115.00 | AvgR:122.04 | Score: 23 | AvgS:19.14 | Eps:0.0500 | Steps: 355
# Ep:29870 | Reward:  68.00 | AvgR:122.23 | Score: 11 | AvgS:19.10 | Eps:0.0500 | Steps: 197
# Ep:29871 | Reward: 293.50 | AvgR:123.69 | Score: 48 | AvgS:19.39 | Eps:0.0500 | Steps: 810
# Ep:29872 | Reward:  97.00 | AvgR:123.15 | Score: 16 | AvgS:19.28 | Eps:0.0500 | Steps: 269
# Ep:29873 | Reward: 210.50 | AvgR:123.46 | Score: 30 | AvgS:19.31 | Eps:0.0500 | Steps: 557
# Ep:29874 | Reward:  36.50 | AvgR:123.30 | Score: 10 | AvgS:19.34 | Eps:0.0500 | Steps: 138
# Ep:29875 | Reward:   6.00 | AvgR:121.50 | Score:  3 | AvgS:19.12 | Eps:0.0500 | Steps:  51
# Ep:29876 | Reward: 140.00 | AvgR:122.30 | Score: 19 | AvgS:19.22 | Eps:0.0500 | Steps: 355
# Ep:29877 | Reward: 188.00 | AvgR:122.29 | Score: 31 | AvgS:19.20 | Eps:0.0500 | Steps: 514
# Ep:29878 | Reward:  95.00 | AvgR:121.08 | Score: 17 | AvgS:19.05 | Eps:0.0500 | Steps: 281
# Ep:29879 | Reward: 123.50 | AvgR:120.61 | Score: 19 | AvgS:18.98 | Eps:0.0500 | Steps: 330
# Ep:29880 | Reward:  71.50 | AvgR:120.06 | Score:  9 | AvgS:18.85 | Eps:0.0500 | Steps: 202
# Ep:29881 | Reward: 205.50 | AvgR:119.93 | Score: 32 | AvgS:18.88 | Eps:0.0500 | Steps: 586
# Ep:29882 | Reward: 104.00 | AvgR:120.81 | Score: 20 | AvgS:19.04 | Eps:0.0500 | Steps: 345
# Ep:29883 | Reward:  45.50 | AvgR:120.71 | Score: 11 | AvgS:19.03 | Eps:0.0500 | Steps: 154
# Ep:29884 | Reward: 169.50 | AvgR:120.42 | Score: 27 | AvgS:19.03 | Eps:0.0500 | Steps: 458
# Ep:29885 | Reward:   3.00 | AvgR:119.46 | Score:  2 | AvgS:18.94 | Eps:0.0500 | Steps:  41
# Ep:29886 | Reward: 174.00 | AvgR:120.91 | Score: 32 | AvgS:19.19 | Eps:0.0500 | Steps: 460
# Ep:29887 | Reward:  53.00 | AvgR:120.57 | Score:  9 | AvgS:19.10 | Eps:0.0500 | Steps: 165
# Ep:29888 | Reward: 183.00 | AvgR:120.12 | Score: 30 | AvgS:19.08 | Eps:0.0500 | Steps: 481
# Ep:29889 | Reward: 214.00 | AvgR:120.39 | Score: 31 | AvgS:19.13 | Eps:0.0500 | Steps: 565
# Ep:29890 | Reward:  89.00 | AvgR:120.86 | Score: 15 | AvgS:19.15 | Eps:0.0500 | Steps: 255
# Ep:29891 | Reward:  44.00 | AvgR:120.73 | Score:  7 | AvgS:19.10 | Eps:0.0500 | Steps: 137
# Ep:29892 | Reward:  46.00 | AvgR:119.44 | Score:  7 | AvgS:18.98 | Eps:0.0500 | Steps: 149
# Ep:29893 | Reward: 148.50 | AvgR:119.04 | Score: 22 | AvgS:18.94 | Eps:0.0500 | Steps: 420
# Ep:29894 | Reward: 103.00 | AvgR:119.16 | Score: 19 | AvgS:18.97 | Eps:0.0500 | Steps: 299
# Ep:29895 | Reward: 106.00 | AvgR:117.39 | Score: 20 | AvgS:18.73 | Eps:0.0500 | Steps: 349
# Ep:29896 | Reward: 149.00 | AvgR:118.10 | Score: 23 | AvgS:18.84 | Eps:0.0500 | Steps: 399
# Ep:29897 | Reward: 113.00 | AvgR:117.78 | Score: 24 | AvgS:18.88 | Eps:0.0500 | Steps: 334
# Ep:29898 | Reward: 107.50 | AvgR:118.33 | Score: 16 | AvgS:18.90 | Eps:0.0500 | Steps: 292
# Ep:29899 | Reward: 148.00 | AvgR:116.42 | Score: 23 | AvgS:18.72 | Eps:0.0500 | Steps: 397
# Ep:29900 | Reward:  18.50 | AvgR:115.91 | Score:  6 | AvgS:18.68 | Eps:0.0500 | Steps:  94
# Ep:29901 | Reward:  93.50 | AvgR:116.33 | Score: 17 | AvgS:18.77 | Eps:0.0500 | Steps: 278
# Ep:29902 | Reward: 133.00 | AvgR:116.42 | Score: 24 | AvgS:18.82 | Eps:0.0500 | Steps: 417
# Ep:29903 | Reward: 108.50 | AvgR:116.27 | Score: 21 | AvgS:18.83 | Eps:0.0500 | Steps: 364
# Ep:29904 | Reward:  25.00 | AvgR:114.78 | Score:  4 | AvgS:18.62 | Eps:0.0500 | Steps:  97
# Ep:29905 | Reward: 333.50 | AvgR:115.72 | Score: 50 | AvgS:18.77 | Eps:0.0500 | Steps: 928
# Ep:29906 | Reward:  61.00 | AvgR:115.01 | Score: 10 | AvgS:18.66 | Eps:0.0500 | Steps: 175
# Ep:29907 | Reward:  88.00 | AvgR:113.03 | Score: 15 | AvgS:18.40 | Eps:0.0500 | Steps: 263
# Ep:29908 | Reward: 221.00 | AvgR:114.18 | Score: 31 | AvgS:18.56 | Eps:0.0500 | Steps: 579
# Ep:29909 | Reward: 162.50 | AvgR:114.39 | Score: 28 | AvgS:18.67 | Eps:0.0500 | Steps: 446
# Ep:29910 | Reward:  61.50 | AvgR:114.20 | Score: 10 | AvgS:18.61 | Eps:0.0500 | Steps: 186
# Ep:29911 | Reward: 143.50 | AvgR:114.71 | Score: 27 | AvgS:18.76 | Eps:0.0500 | Steps: 473
# Ep:29912 | Reward: 158.00 | AvgR:115.91 | Score: 23 | AvgS:18.91 | Eps:0.0500 | Steps: 443
# Ep:29913 | Reward: 135.00 | AvgR:117.05 | Score: 17 | AvgS:19.01 | Eps:0.0500 | Steps: 369
# Ep:29914 | Reward:  73.50 | AvgR:116.73 | Score: 15 | AvgS:18.90 | Eps:0.0500 | Steps: 230
# Ep:29915 | Reward:  46.00 | AvgR:115.98 | Score:  9 | AvgS:18.82 | Eps:0.0500 | Steps: 143
# Ep:29916 | Reward: 352.00 | AvgR:118.60 | Score: 50 | AvgS:19.16 | Eps:0.0500 | Steps: 935
# Ep:29917 | Reward: 216.00 | AvgR:120.36 | Score: 33 | AvgS:19.40 | Eps:0.0500 | Steps: 575
# Ep:29918 | Reward: 202.00 | AvgR:121.08 | Score: 29 | AvgS:19.46 | Eps:0.0500 | Steps: 533
# Ep:29919 | Reward: 147.00 | AvgR:121.52 | Score: 22 | AvgS:19.52 | Eps:0.0500 | Steps: 392
# Ep:29920 | Reward: 213.00 | AvgR:123.01 | Score: 27 | AvgS:19.72 | Eps:0.0500 | Steps: 587
# Ep:29921 | Reward: 105.50 | AvgR:122.21 | Score: 20 | AvgS:19.62 | Eps:0.0500 | Steps: 307
# Ep:29922 | Reward: 147.00 | AvgR:121.42 | Score: 21 | AvgS:19.48 | Eps:0.0500 | Steps: 389
# Ep:29923 | Reward:  42.50 | AvgR:120.94 | Score:  9 | AvgS:19.43 | Eps:0.0500 | Steps: 137
# Ep:29924 | Reward: 279.50 | AvgR:123.48 | Score: 44 | AvgS:19.81 | Eps:0.0500 | Steps: 746
# Ep:29925 | Reward: 107.50 | AvgR:122.98 | Score: 22 | AvgS:19.72 | Eps:0.0500 | Steps: 328
# Ep:29926 | Reward: 162.50 | AvgR:122.13 | Score: 22 | AvgS:19.66 | Eps:0.0500 | Steps: 420
# Ep:29927 | Reward: 148.00 | AvgR:122.89 | Score: 23 | AvgS:19.77 | Eps:0.0500 | Steps: 401
# Ep:29928 | Reward:  55.50 | AvgR:123.25 | Score: 12 | AvgS:19.82 | Eps:0.0500 | Steps: 178
# Ep:29929 | Reward: 120.50 | AvgR:124.17 | Score: 19 | AvgS:19.92 | Eps:0.0500 | Steps: 332
# Ep:29930 | Reward: 103.50 | AvgR:123.74 | Score: 16 | AvgS:19.83 | Eps:0.0500 | Steps: 290
# Ep:29931 | Reward:  95.00 | AvgR:123.95 | Score: 12 | AvgS:19.78 | Eps:0.0500 | Steps: 257
# Ep:29932 | Reward:  37.00 | AvgR:122.53 | Score:  9 | AvgS:19.59 | Eps:0.0500 | Steps: 129
# Ep:29933 | Reward:  23.50 | AvgR:120.98 | Score:  6 | AvgS:19.36 | Eps:0.0500 | Steps: 100
# Ep:29934 | Reward: 356.00 | AvgR:123.75 | Score: 48 | AvgS:19.68 | Eps:0.0500 | Steps: 963
# Ep:29935 | Reward: 157.00 | AvgR:123.36 | Score: 21 | AvgS:19.62 | Eps:0.0500 | Steps: 405
# Ep:29936 | Reward:  34.50 | AvgR:121.65 | Score:  4 | AvgS:19.35 | Eps:0.0500 | Steps: 108
# Ep:29937 | Reward: 194.00 | AvgR:123.43 | Score: 32 | AvgS:19.63 | Eps:0.0500 | Steps: 538
# Ep:29938 | Reward: 179.00 | AvgR:123.23 | Score: 27 | AvgS:19.56 | Eps:0.0500 | Steps: 458
# Ep:29939 | Reward: 136.00 | AvgR:122.88 | Score: 22 | AvgS:19.51 | Eps:0.0500 | Steps: 366
# Ep:29940 | Reward: 228.00 | AvgR:124.03 | Score: 43 | AvgS:19.75 | Eps:0.0500 | Steps: 626
# Ep:29941 | Reward: 182.50 | AvgR:125.66 | Score: 24 | AvgS:19.95 | Eps:0.0500 | Steps: 478
# Ep:29942 | Reward:  84.50 | AvgR:125.32 | Score: 15 | AvgS:19.94 | Eps:0.0500 | Steps: 240
# Ep:29943 | Reward: 266.50 | AvgR:126.64 | Score: 41 | AvgS:20.13 | Eps:0.0500 | Steps: 727
# Ep:29944 | Reward:  29.00 | AvgR:126.00 | Score:  7 | AvgS:20.06 | Eps:0.0500 | Steps: 105
# Ep:29945 | Reward: 204.50 | AvgR:126.16 | Score: 25 | AvgS:20.03 | Eps:0.0500 | Steps: 508
# Ep:29946 | Reward: 182.00 | AvgR:127.67 | Score: 29 | AvgS:20.28 | Eps:0.0500 | Steps: 471
# Ep:29947 | Reward:  12.50 | AvgR:127.25 | Score:  4 | AvgS:20.26 | Eps:0.0500 | Steps:  72
# Ep:29948 | Reward: 297.50 | AvgR:129.82 | Score: 41 | AvgS:20.59 | Eps:0.0500 | Steps: 770
# Ep:29949 | Reward: 150.50 | AvgR:130.77 | Score: 25 | AvgS:20.76 | Eps:0.0500 | Steps: 426
# Ep:29950 | Reward: 105.00 | AvgR:128.99 | Score: 15 | AvgS:20.50 | Eps:0.0500 | Steps: 273
# Ep:29951 | Reward:  97.00 | AvgR:127.03 | Score: 15 | AvgS:20.30 | Eps:0.0500 | Steps: 279
# Ep:29952 | Reward: 139.00 | AvgR:126.70 | Score: 23 | AvgS:20.24 | Eps:0.0500 | Steps: 375
# Ep:29953 | Reward: 181.50 | AvgR:126.56 | Score: 34 | AvgS:20.34 | Eps:0.0500 | Steps: 592
# Ep:29954 | Reward:  61.50 | AvgR:126.45 | Score: 10 | AvgS:20.31 | Eps:0.0500 | Steps: 194
# Ep:29955 | Reward:   4.50 | AvgR:124.95 | Score:  2 | AvgS:20.11 | Eps:0.0500 | Steps:  48
# Ep:29956 | Reward: 190.00 | AvgR:126.22 | Score: 27 | AvgS:20.29 | Eps:0.0500 | Steps: 479
# Ep:29957 | Reward: 120.00 | AvgR:126.11 | Score: 19 | AvgS:20.26 | Eps:0.0500 | Steps: 329
# Ep:29958 | Reward: 261.50 | AvgR:128.15 | Score: 37 | AvgS:20.55 | Eps:0.0500 | Steps: 680
# Ep:29959 | Reward:  70.00 | AvgR:127.27 | Score: 10 | AvgS:20.36 | Eps:0.0500 | Steps: 211
# Ep:29960 | Reward:  46.50 | AvgR:126.41 | Score:  6 | AvgS:20.20 | Eps:0.0500 | Steps: 138
# Ep:29961 | Reward:  74.50 | AvgR:125.59 | Score: 14 | AvgS:20.14 | Eps:0.0500 | Steps: 232
# Ep:29962 | Reward: 157.00 | AvgR:126.41 | Score: 16 | AvgS:20.13 | Eps:0.0500 | Steps: 387
# Ep:29963 | Reward:  38.00 | AvgR:126.58 | Score:  8 | AvgS:20.17 | Eps:0.0500 | Steps: 135
# Ep:29964 | Reward:  82.00 | AvgR:126.80 | Score: 16 | AvgS:20.25 | Eps:0.0500 | Steps: 251
# Ep:29965 | Reward: 147.50 | AvgR:126.57 | Score: 23 | AvgS:20.18 | Eps:0.0500 | Steps: 396
# Ep:29966 | Reward:  28.00 | AvgR:126.70 | Score:  8 | AvgS:20.21 | Eps:0.0500 | Steps: 127
# Ep:29967 | Reward: 152.50 | AvgR:127.73 | Score: 25 | AvgS:20.36 | Eps:0.0500 | Steps: 434
# Ep:29968 | Reward:  39.00 | AvgR:127.58 | Score: 10 | AvgS:20.35 | Eps:0.0500 | Steps: 135
# Ep:29969 | Reward: 178.00 | AvgR:128.22 | Score: 31 | AvgS:20.43 | Eps:0.0500 | Steps: 533
# Ep:29970 | Reward:  32.50 | AvgR:127.86 | Score:  7 | AvgS:20.39 | Eps:0.0500 | Steps: 114
# Ep:29971 | Reward: 114.00 | AvgR:126.06 | Score: 17 | AvgS:20.08 | Eps:0.0500 | Steps: 315
# Ep:29972 | Reward: 156.50 | AvgR:126.66 | Score: 25 | AvgS:20.17 | Eps:0.0500 | Steps: 420
# Ep:29973 | Reward:  59.50 | AvgR:125.15 | Score: 12 | AvgS:19.99 | Eps:0.0500 | Steps: 175
# Ep:29974 | Reward: 117.00 | AvgR:125.95 | Score: 20 | AvgS:20.09 | Eps:0.0500 | Steps: 331
# Ep:29975 | Reward: 160.00 | AvgR:127.50 | Score: 22 | AvgS:20.28 | Eps:0.0500 | Steps: 433
# Ep:29976 | Reward: 114.50 | AvgR:127.24 | Score: 20 | AvgS:20.29 | Eps:0.0500 | Steps: 316
# Ep:29977 | Reward:  80.50 | AvgR:126.17 | Score: 19 | AvgS:20.17 | Eps:0.0500 | Steps: 248
# Ep:29978 | Reward:  47.00 | AvgR:125.69 | Score: 10 | AvgS:20.10 | Eps:0.0500 | Steps: 151
# Ep:29979 | Reward:  39.00 | AvgR:124.84 | Score: 16 | AvgS:20.07 | Eps:0.0500 | Steps: 159
# Ep:29980 | Reward: 128.00 | AvgR:125.41 | Score: 16 | AvgS:20.14 | Eps:0.0500 | Steps: 333
# Ep:29981 | Reward:  18.00 | AvgR:123.53 | Score:  5 | AvgS:19.87 | Eps:0.0500 | Steps:  83
# Ep:29982 | Reward: 145.00 | AvgR:123.94 | Score: 23 | AvgS:19.90 | Eps:0.0500 | Steps: 435
# Ep:29983 | Reward: 121.50 | AvgR:124.70 | Score: 14 | AvgS:19.93 | Eps:0.0500 | Steps: 320
# Ep:29984 | Reward: 163.00 | AvgR:124.64 | Score: 20 | AvgS:19.86 | Eps:0.0500 | Steps: 441
# Ep:29985 | Reward:  91.00 | AvgR:125.52 | Score: 19 | AvgS:20.03 | Eps:0.0500 | Steps: 270
# Ep:29986 | Reward: 178.00 | AvgR:125.56 | Score: 28 | AvgS:19.99 | Eps:0.0500 | Steps: 496
# Ep:29987 | Reward: 122.00 | AvgR:126.25 | Score: 21 | AvgS:20.11 | Eps:0.0500 | Steps: 323
# Ep:29988 | Reward:  76.50 | AvgR:125.18 | Score: 14 | AvgS:19.95 | Eps:0.0500 | Steps: 232
# Ep:29989 | Reward: 124.50 | AvgR:124.28 | Score: 16 | AvgS:19.80 | Eps:0.0500 | Steps: 338
# Ep:29990 | Reward: 189.00 | AvgR:125.28 | Score: 27 | AvgS:19.92 | Eps:0.0500 | Steps: 523
# Ep:29991 | Reward:  48.50 | AvgR:125.33 | Score: 10 | AvgS:19.95 | Eps:0.0500 | Steps: 170
# Ep:29992 | Reward:  40.50 | AvgR:125.28 | Score:  9 | AvgS:19.97 | Eps:0.0500 | Steps: 140
# Ep:29993 | Reward:  73.00 | AvgR:124.52 | Score: 14 | AvgS:19.89 | Eps:0.0500 | Steps: 221
# Ep:29994 | Reward:  20.50 | AvgR:123.69 | Score:  9 | AvgS:19.79 | Eps:0.0500 | Steps: 106
# Ep:29995 | Reward: 127.50 | AvgR:123.91 | Score: 20 | AvgS:19.79 | Eps:0.0500 | Steps: 354
# Ep:29996 | Reward: 135.00 | AvgR:123.77 | Score: 26 | AvgS:19.82 | Eps:0.0500 | Steps: 362
# Ep:29997 | Reward:  80.00 | AvgR:123.44 | Score: 12 | AvgS:19.70 | Eps:0.0500 | Steps: 239
# Ep:29998 | Reward: 183.00 | AvgR:124.19 | Score: 30 | AvgS:19.84 | Eps:0.0500 | Steps: 477
# Ep:29999 | Reward:  66.00 | AvgR:123.38 | Score: 15 | AvgS:19.76 | Eps:0.0500 | Steps: 213
#
# 🎉 Training complete!
# Best score achieved: 0
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
